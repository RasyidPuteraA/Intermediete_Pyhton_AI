# %% [markdown]
# # Assingment
# 1. Create a 4x4 matrix with values ranging from 0 to 3.
# 2. Create an array with shape of 4x4 and turn it into two arrays along the second axis.

# %%
import numpy as np
from numpy import random

# %%
#1
y = random.randint(0,4, size=(4,4))
y

# %%
#2
x = np.arange(16).reshape((4, 4))
x = np.hsplit(x, [2, 2])
print(x)

# %%
import os
from google.colab import drive
drive.mount('/content/drive')

# %%
dir = '/content/drive/MyDrive/Colab Notebooks/Intermediete_AI'

# %%
np.save(os.path.join(dir, "y"), y)

# %%
np.savetxt('/content/drive/MyDrive/Colab Notebooks/Intermediete_AI/y.csv', y)

# %%
np.loadtxt('/content/drive/MyDrive/Colab Notebooks/Intermediete_AI/y.csv')
